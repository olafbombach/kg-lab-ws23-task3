# %%
import numpy as np
import pandas as pd
from source.wikidataquery import WikidataQuery
# Out:
# {'head': {'vars': ['item', 'itemLabel']}, 'results': {'bindings': [{'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q378619'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'CC'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q498787'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Muezza'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q677525'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Orangey'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q851190'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mrs. Chippy'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q893453'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Unsinkable Sam'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1050083'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Catmando'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1185550'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Oscar'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1201902'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Tama'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1207136'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Dewey Readmore Books'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1371145'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Socks'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1386318'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'F. D. C. Willard'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1413628'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Nora'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1622688'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Hodge'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1637234'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Humphrey'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1750907'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Towser'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q1759652'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Wilberforce'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2060630'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'India'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2098929'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Simon'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2262318'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Larry'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2300851'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Winnie'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2597104'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Creme Puff'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2624688'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Sybil'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2634968'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Maru'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q2909987'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Mr. Green Genes'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q4421603'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Scarlett'}}, {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q5049074'}, 'itemLabel': {'xml:lang': 'en', 'type': 'literal', 'value': 'Casp ...

# %% [markdown]
# ## Let's consider the number of total academic conferences of Wikidata (P31/instance of='academic conference')

# %%
temp = WikidataQuery.queryWikiData(
    '''SELECT
    # ?conferencesLabel
    # ?seriesLabel
    # ?short_name
    # ?beginnings
    # ?WikiCFP_identifier
    # ?DBLP_identifier

    WHERE {
    # ?conferences wdt:P31 wd:Q2020153.

    OPTIONAL {
    # ?conferences wdt:P179 ?series.
    OPTIONAL { ?series wdt:P1813 ?short_name. }
    OPTIONAL { ?series wdt:P571 ?beginnings. }
    OPTIONAL { ?series wdt:P5127 ?WikiCFP_identifier. }
    OPTIONAL { ?series wdt:P8926 ?DBLP_identifier. }
    }

    SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en".
    }
}''')

# %%
# untangling the results in order to get a dataframe

results = temp['results']['bindings']

conf_labels = np.array([result['conferencesLabel']['value'] for result in results])
series_labels = np.array([result['seriesLabel']['value'] if 'seriesLabel' in result.keys() else pd.NA for result in results])
short_name = np.array([result['short_name']['value'] if 'short_name' in result.keys() else pd.NA for result in results])
beginnings = np.array([result['beginnings']['value'] if 'beginnings' in result.keys() else pd.NA for result in results])
wikicfp_identifier = np.array([result['WikiCFP_identifier']['value'] if 'WikiCFP_identifier' in result.keys() else pd.NA for result in results])
dblp_identifier = np.array([result['DBLP_identifier']['value'] if 'DBLP_identifier' in result.keys() else pd.NA for result in results])

# %%
# zip all arrays together to create a DataFrame

together = zip(conf_labels, series_labels, short_name, beginnings, wikicfp_identifier, dblp_identifier)

df = pd.DataFrame(together, columns=['conf_labels', 'series_labels', 'short_name', 'beginnings', 'WikiCFP_identifier', 'DBLP_identifier'])
df.sample(200, random_state=42)
# Out:
#                                             conf_labels  \
# 4575  Advances in Artificial Life, 6th European Conf...
# 1488  Data Security and Security Data - 27th British...
# 4970  14th International Conference on Semantic Syst...
# 7333                            Colloquium Mosbach 1978
# 3027  7th International Conference on Hardware/Softw...
# ...                                                 ...
# 6916  The 2006 Conference on Empirical Methods in Na...
# 5993  Equation-Based Object-Oriented Modeling Langua...
# 5664  Seventh International Conference on Computatio...
# 718   12th IEEE/ACM Working Conference on Mining Sof...
# 7231               Lernen, Wissen, Daten, Analysen 2017
#
#                                           series_labels  short_name  \
# 4575             European Conference on Artificial Life        ECAL
# 1488      British International Conference on Databases       BICOD
# 4970       International Conference on Semantic Systems   SEMANTICS
# 7333                                 Colloquium Mosbach        <NA>
# 3027  International Conference on Hardware/Software ...  CODES+ISSS
# ...                                                 ...         ...
# 6916   Empirical Methods in Natural Language Processing       EMNLP
# 5993  International Workshop on Equation-Based Objec...       EOOLT
# 5664  International Conference on Computational Crea...        ICCC
# 718   IEEE Working Conference on Mining Software Rep...         MSR
# 7231                    Lernen, Wissen, Daten, Analysen        LWDA
#
#                 beginnings WikiCFP_identifier   DBLP_identifier
# 4575                  <NA>                794         conf/ecal
# 1488  1981-01-01T00:00:00Z                317        conf/bncod
# 4970                  <NA>               1705  conf/i-semantics
# 7333  1950-01-01T00:00:00Z               <NA>              <NA>
# 3027                  <NA>               <NA>    conf/codesisss
# ...                    ...                ...               ...
# 6916  1996-01-01T00:00:00Z                883        conf/emnlp
# 5993                  <NA>                894        conf/eoolt
# 5664  2010-01-01T00:00:00Z               <NA>      conf/icccrea
# 718                   <NA>               2148          conf/msr
# 7231  1999-01-01T00:00:00Z               <NA>          conf/lwa
#
# [200 rows x 6 columns]

# %%
print(df.shape)
df.isna().sum()
# Out:
# (8911, 6)
# conf_labels              0
# series_labels         1040
# short_name            1558
# beginnings            6364
# WikiCFP_identifier    5239
# DBLP_identifier       1541
# dtype: int64

# %% [markdown]
# # Let's check an example and its possible queries for the different databases:
#
# example: conference series IWCMC

# %%
df.loc[df['short_name'] == 'IWCMC']
# Out:
#                                             conf_labels  \
# 3607  7th International Wireless Communications and ...
# 5427  2016 International Wireless Communications and...
# 5428  International Wireless Communications and Mobi...
# 5430  International Conference on Wireless Communica...
# 5431  6th International Wireless Communications and ...
# 5432  International Conference on Wireless Communica...
# 7546  International Conference on Wireless Communica...
#
#                                           series_labels short_name beginnings  \
# 3607  International Conference on Wireless Communica...      IWCMC       <NA>
# 5427  International Conference on Wireless Communica...      IWCMC       <NA>
# 5428  International Conference on Wireless Communica...      IWCMC       <NA>
# 5430  International Conference on Wireless Communica...      IWCMC       <NA>
# 5431  International Conference on Wireless Communica...      IWCMC       <NA>
# 5432  International Conference on Wireless Communica...      IWCMC       <NA>
# 7546  International Conference on Wireless Communica...      IWCMC       <NA>
#
#      WikiCFP_identifier DBLP_identifier
# 3607               1824      conf/iwcmc
# 5427               1824      conf/iwcmc
# 5428               1824      conf/iwcmc
# 5430               1824      conf/iwcmc
# 5431               1824      conf/iwcmc
# 5432               1824      conf/iwcmc
# 7546               1824      conf/iwcmc

# %% [markdown]
# ## In Wikidata:
# events for the years: 2007, 2009, 2010, 2011, 2014, 2016 and 2022
# --> I also could not find other entries that are just not connected to the series...
# _________________________________________________________________________________________________________
#
# ## In WikiCFP:
# events for the years: <b>2008</b>, 2009, 2010, <b>2012</b>, <b>2013</b>, 2016 and <b>2017</b>
# http://www.wikicfp.com/cfp/program?id=1824&s=IWCMC&f=International%20Conference%20on%20Wireless%20Communications%20and%20Mobile%20Computing
#
# ## In DBLP:
# events for the years: <b>2006</b>, 2007, 2009, 2010, 2011, <b>2012</b>, <b>2013</b>, 2014, <b>2015</b>, 2016, <b>2017</b>, <b>2018</b>, <b>2019</b>, <b>2020</b>, <b>2021</b>, 2022, <b>2023</b>
# https://dblp.org/db/conf/iwcmc/index.html
# every series is well organized
#
# ## In Crossref:
# https://search.crossref.org/search/works?q=iwcmc&from_ui=yes
# There is a lot of unorganized information about this conference series. There is no such thing as the overall conference series with an enumeration of all events. Structuring could be a lot of work.
#
# ## In CORE:
# https://core.ac.uk/search?q=iwcmc
# There only seems to be information about papers. Maybe we can use the papers property in order to deduce information about conference events.
#
# ## In BASE:
# https://www.base-search.net/Search/Results?type=all&lookfor=IWCMC&ling=1&oaboost=1&keepFilters=1&filter%5B%5D=f_dctypenorm%3A%2213%22&name=&thes=&refid=dcresde&newsearch=1
# Information seems to be a bit more organized than in Crossref. All information seems to be imported from Crossref though.
# The reference to the events are directed to IEEE. Here we also get a list of all conference events:
#
# ## In IEEE:
# https://ieeexplore.ieee.org/xpl/conhome/1002410/all-proceedings
# events for the years: <b>2008</b>, 2011, <b>2012</b>, <b>2013</b>, 2014, <b>2015</b>, 2016, <b>2017</b>, <b>2018</b>, <b>2019</b>, <b>2020</b>, <b>2021</b>, 2022 and <b>2023</b>

# %% [markdown]
# # Also there are duplicates: Should we merge those?

# %%
groupedby_dblp_df = df.groupby('DBLP_identifier').agg(set)
groupedby_dblp_df
# Out:
#                                                        conf_labels  \
# DBLP_identifier
# conf/3dica       {Scaling Topic Maps, Third International Confe...
# conf/3dim        {Fourth International Conference on 3D Vision,...
# conf/3dui        {3DUI 2007, 3DUI 2015, 3DUI 2010, 3DUI 2016, 3...
# conf/5gwf        {2nd IEEE 5G World Forum, 5GWF 2019, Dresden, ...
# conf/5gwn        {5G for Future Wireless Networks - 2nd EAI Int...
# ...                                                            ...
# conf/www         {23rd International World Wide Web Conference,...
# conf/xps         {Digital Bildverarbeitung - Digital Image Proc...
# conf/xpu         {Agile Processes in Software Engineering and E...
# conf/xsede       {Practice and Experience in Advanced Research ...
# conf/zum         {Rigorous State-Based Methods - 7th Internatio...
#
#                                                      series_labels short_name  \
# DBLP_identifier
# conf/3dica       {Three-Dimensional Image Processing, Measureme...    {3DIPM}
# conf/3dim                  {International Conference on 3D Vision}      {3DV}
# conf/3dui                   {IEEE Symposium on 3D User Interfaces}     {3DUI}
# conf/5gwf                                         {5G World Forum}     {5GWF}
# conf/5gwn        {International Conference on 5G for Future Wir...     {5GWN}
# ...                                                            ...        ...
# conf/www                                      {The Web Conference}      {WWW}
# conf/xps            {German Conference on Knowledge-Based Systems}      {XPS}
# conf/xpu         {International Conference on Agile Software De...       {XP}
# conf/xsede       {Practice and Experience in Advanced Research ...    {PEARC}
# conf/zum         {International Conference on Abstract State Ma...      {ABZ}
#
#                              beginnings WikiCFP_identifier
# DBLP_identifier
# conf/3dica       {1998-01-01T00:00:00Z}             {<NA>}
# conf/3dim                        {<NA>}             {<NA>}
# conf/3dui                        {<NA>}             {<NA>}
# conf/5gwf        {2018-01-01T00:00:00Z}             {<NA>}
# conf/5gwn        {2017-01-01T00:00:00Z}             {<NA>}
# ...                                 ...                ...
# conf/www         {1994-01-01T00:00:00Z}             {3182}
# conf/xps                         {<NA>}             {<NA>}
# conf/xpu                         {<NA>}             {3186}
# conf/xsede                       {<NA>}             {<NA>}
# conf/zum                         {<NA>}               {13}
#
# [2028 rows x 5 columns]

# %%
groupedby_dblp_df = groupedby_dblp_df.assign(length = groupedby_dblp_df['series_labels'].apply(len))

# %%
groupedby_dblp_df.loc[groupedby_dblp_df['length'] > 1]
# Out:
#                                                        conf_labels  \
# DBLP_identifier
# conf/ecml        {Machine Learning: EMCL 2001, 12th European Co...
#
#                                                      series_labels  \
# DBLP_identifier
# conf/ecml        {European Conference on Machine Learning, Euro...
#
#                         short_name beginnings WikiCFP_identifier  length
# DBLP_identifier
# conf/ecml        {ECML PKDD, ECML}     {<NA>}             {<NA>}       2

# %%
groupedby_shortname_df = df.groupby('short_name').agg(set)
groupedby_shortname_df
# Out:
#                                                   conf_labels  \
# short_name
# *SEM        {The Eighth Joint Conference on Lexical and Co...
# 3DIPM       {Scaling Topic Maps, Third International Confe...
# 3DUI        {3DUI 2007, 3DUI 2015, 3DUI 2010, 3DUI 2016, 3...
# 3DV         {Fourth International Conference on 3D Vision,...
# 3GSE        {28th USENIX Security Symposium, USENIX Securi...
# ...                                                       ...
# iNetSeC     {Geospatial Free and Open Source Software in t...
# iTAG        {2014 International Conference on Interactive ...
# icSPORTS    {4th International Congress on Sport Sciences ...
# iiWAS       {15th International Conference on Information ...
# jAUTI       {Applications and Usability of Interactive TV ...
#
#                                                 series_labels  \
# short_name
# *SEM        {Joint Conference on Lexical and Computational...
# 3DIPM       {Three-Dimensional Image Processing, Measureme...
# 3DUI                   {IEEE Symposium on 3D User Interfaces}
# 3DV                   {International Conference on 3D Vision}
# 3GSE                              {USENIX Security Symposium}
# ...                                                       ...
# iNetSeC          {Open Research Problems in Network Security}
# iTAG        {International Conference on Interactive Techn...
# icSPORTS    {International Congress on Sport Sciences Rese...
# iiWAS       {International Conference on Information Integ...
# jAUTI       {Iberoamerican Conference on Applications and ...
#
#                         beginnings WikiCFP_identifier  DBLP_identifier
# short_name
# *SEM                        {<NA>}             {<NA>}   {conf/starsem}
# 3DIPM       {1998-01-01T00:00:00Z}             {<NA>}     {conf/3dica}
# 3DUI                        {<NA>}             {<NA>}      {conf/3dui}
# 3DV                         {<NA>}             {<NA>}      {conf/3dim}
# 3GSE                        {<NA>}             {<NA>}       {conf/uss}
# ...                            ...                ...              ...
# iNetSeC                     {<NA>}             {<NA>}  {conf/ifip11-4}
# iTAG                        {<NA>}             {<NA>}      {conf/itag}
# icSPORTS                    {<NA>}             {<NA>}  {conf/icsports}
# iiWAS                       {<NA>}             {<NA>}     {conf/iiwas}
# jAUTI                       {<NA>}             {<NA>}     {conf/jauti}
#
# [1940 rows x 5 columns]

# %%
groupedby_shortname_df = groupedby_shortname_df.assign(length = groupedby_shortname_df['series_labels'].apply(len))

# %%
groupedby_shortname_df.loc[groupedby_shortname_df['length'] > 1]
# Out:
#                                                   conf_labels  \
# short_name
# ACE         {Sixth Australasian Computing Education Confer...
# ACL         {The 57th Annual Meeting of the Association fo...
# ACSAC       {ACSAC '20: Annual Computer Security Applicati...
# AH          {AH '20: 11th Augmented Human International Co...
# AIM         {2ème Journée AIM de recherche Serious Games e...
# AIPR        {2nd International Conference on Artificial In...
# BDA         {Big Data Analytics - 4th International Confer...
# CCS         {17th ACM Conference on Computer and Communica...
# CIC         {1st Color and Imaging Conference, CIC 1993, S...
# CISIS       {International Joint Conference - CISIS'15 and...
# CMC         {Cooperative Multimodal Communication, Second ...
# CSWS        {Semantic Web and Web Science - 8th Chinese Co...
# DH          {ALLC-ACH 1997, 2018 International Conference ...
# ECBS        {2016 IEEE International Conference on Pervasi...
# FG          {Formal Grammar - 22nd International Conferenc...
# HIS         {Health Information Science - 5th Internationa...
# HPCA        {7th Conference on High-Performance Graphics, ...
# HPCS        {2012 International Conference on High Perform...
# HSI         {Web Communication Technologies and Internet-R...
# ICAIS       {Adaptive and Intelligent Systems - Second Int...
# ICAT        {Advances in Artificial Reality and Tele-Exist...
# ICC         {2019 IEEE International Conference on Communi...
# ICCC        {International Conference on Computer Communic...
# ICCIP       {4th International Conference on Communication...
# ICCS        {Seventh International Conference on Chemical ...
# ICDM        {Advances in Data Mining: Applications and The...
# ICEC        {7th International Conference on Electronic Co...
# ICICS       {Information and Communications Security - 22n...
# ICIS        {2014 IEEE/ACIS 13th International Conference ...
# ICON        {IEEE International Conference on Networks 199...
# ICSC        {Tenth IEEE International Conference on Semant...
# ICVS        {Computer Vision Systems - 11th International ...
# IDC         {Intelligent Distributed Computing, Systems an...
# IHCI        {Intelligent Human Computer Interaction - 12th...
# ISCO        {Information System Concepts: Improving the Un...
# ISI         {Pragmatische Aspekte beim Entwurf und Betrieb...
# ISPA        {11th International Symposium on Image and Sig...
# ITC         {2009 IEEE International Test Conference, ITC ...
# IV          {16th International Conference on Information ...
# JIST        {Semantic Technology - 9th Joint International...
# MCPR        {17th International Conference on Information ...
# MobiSec     {Mobile Internet Security - Second Internation...
# PROMISE     {Information Retrieval Meets Information Visua...
# PSC         {2019 24th OptoElectronics and Communications ...
# SC          {1st SC@ETAPS 2002: Grenoble, France, Software...
# SDE         {2011 IEEE Symposium on Differential Evolution...
# SEC         {4th ACM/IEEE Symposium on Edge Computing, SEC...
# SSS         {Industrial Perspectives of Safety-critical Sy...
# SoCC        {29th IEEE International System-on-Chip Confer...
# WI          {2019 IEEE/WIC/ACM International Conference on...
#
#                                                 series_labels  \
# short_name
# ACE         {Australasian Computing Education Conference, ...
# ACL         {Proceedings of the conference. Association fo...
# ACSAC       {Annual Computer Security Applications Confere...
# AH          {Augmented Human International Conference, Int...
# AIM         {Conference of the Association Information and...
# AIPR        {International Conference on Artificial Intell...
# BDA         {Journées Bases de Données Avancées, Internati...
# CCS         {Conference on Computer and Communications Sec...
# CIC         {International Conference on Collaboration and...
# CISIS       {International Conference on Complex, Intellig...
# CMC         {Cooperative Multimodal Communication, Interna...
# CSWS        {Canadian Semantic Web Symposium, China Semant...
# DH          {Digital Humanities, International Conference ...
# ECBS        {European Conference on the Engineering of Com...
# FG          {Formal Grammar, IEEE International Conference...
# HIS         {International Conference on Hybrid Intelligen...
# HPCA        {International Symposium on High-Performance C...
# HPCS        {International Conference on High Performance ...
# HSI         {International Conference on Human System Inte...
# ICAIS       {International Conference on Artificial Intell...
# ICAT        {International Conference on Artificial Realit...
# ICC         {International Conference on Internet of Thing...
# ICCC        {International Conference on Computational Cre...
# ICCIP       {International Conference on Critical Infrastr...
# ICCS        {International Conference on Conceptual Struct...
# ICDM        {Industrial Conference on Data Mining, IEEE In...
# ICEC        {International Conference on Electronic Commer...
# ICICS       {International Conference on Information and C...
# ICIS        {IEEE/ACIS International Conference on Compute...
# ICON        {International Conference on Natural Language ...
# ICSC        {International Computer Science Conference, IE...
# ICVS        {International Conference on Computer Vision S...
# IDC         {International Symposium on Intelligent Distri...
# IHCI        {Indian Conference on Human Computer Interacti...
# ISCO        {Information Systems Concepts, International C...
# ISI         {International Symposium of Information Scienc...
# ISPA        {International Symposium on Parallel and Distr...
# ITC         {International Test Conference, Conference on ...
# IV          {IEEE Intelligent Vehicles Symposium, Internat...
# JIST        {Joint International Semantic Technology Confe...
# MCPR        {MCPR Workshops, Mexican Conference on Pattern...
# MobiSec     {International Symposium on Mobile Internet Se...
# PROMISE     {International Conference on Predictive Models...
# PSC         {Photonics in Switching and Computing, Prague ...
# SC          {International Conference on Software Composit...
# SDE         {ACM SIGSOFT/SIGPLAN Software Engineering Symp...
# SEC         {Symposium on Edge Computing, IFIP Internation...
# SSS         {Safety-critical Systems Symposium, Internatio...
# SoCC        {Annual IEEE International System-on-Chip Conf...
# WI          {IEEE/WIC/ACM International Conference on Web ...
#
#                                                    beginnings  \
# short_name
# ACE                              {2004-01-01T00:00:00Z, <NA>}
# ACL                                                    {<NA>}
# ACSAC                                                  {<NA>}
# AH                                                     {<NA>}
# AIM                                                    {<NA>}
# AIPR                                                   {<NA>}
# BDA                              {1985-01-01T00:00:00Z, <NA>}
# CCS                              {1993-01-01T00:00:00Z, <NA>}
# CIC                              {2015-01-01T00:00:00Z, <NA>}
# CISIS                                                  {<NA>}
# CMC                                                    {<NA>}
# CSWS                                                   {<NA>}
# DH               {2008-01-01T00:00:00Z, 1989-01-01T00:00:00Z}
# ECBS                             {2009-01-01T00:00:00Z, <NA>}
# FG                                                     {<NA>}
# HIS                                                    {<NA>}
# HPCA             {1995-01-01T00:00:00Z, 2004-01-01T00:00:00Z}
# HPCS                                                   {<NA>}
# HSI                              {<NA>, 2001-01-01T00:00:00Z}
# ICAIS                            {2015-01-01T00:00:00Z, <NA>}
# ICAT                                                   {<NA>}
# ICC                                                    {<NA>}
# ICCC        {<NA>, 1972-01-01T00:00:00Z, 2010-01-01T00:00:...
# ICCIP                            {2015-01-01T00:00:00Z, <NA>}
# ICCS                             {1987-01-01T00:00:00Z, <NA>}
# ICDM                             {2001-01-01T00:00:00Z, <NA>}
# ICEC                                                   {<NA>}
# ICICS                            {1997-01-01T00:00:00Z, <NA>}
# ICIS                                                   {<NA>}
# ICON                                                   {<NA>}
# ICSC                             {2007-01-01T00:00:00Z, <NA>}
# ICVS                                                   {<NA>}
# IDC                                                    {<NA>}
# IHCI                                                   {<NA>}
# ISCO                                                   {<NA>}
# ISI         {1990-01-01T00:00:00Z, 2012-01-01T00:00:00Z, <...
# ISPA                             {2003-01-01T00:00:00Z, <NA>}
# ITC                              {2005-01-01T00:00:00Z, <NA>}
# IV                               {1997-01-01T00:00:00Z, <NA>}
# JIST                                                   {<NA>}
# MCPR                                                   {<NA>}
# MobiSec                                                {<NA>}
# PROMISE                                                {<NA>}
# PSC                                                    {<NA>}
# SC                                                     {<NA>}
# SDE                                                    {<NA>}
# SEC                                                    {<NA>}
# SSS                                                    {<NA>}
# SoCC                                                   {<NA>}
# WI                               {1993-01-01T00:00:00Z, <NA>}
#
#             WikiCFP_identifier                           DBLP_identifier  \
# short_name
# ACE                   {24, 23}                   {conf/ACMace, conf/ace}
# ACL                 {37, <NA>}                          {conf/acl, <NA>}
# ACSAC                 {45, 46}                 {conf/acsac, conf/aPcsac}
# AH                    {90, 89}                  {conf/aughuman, conf/ah}
# AIM                     {<NA>}                   {conf/aim, conf/aimech}
# AIPR               {117, <NA>}                  {conf/aiprf, conf/aipr2}
# BDA                     {<NA>}                    {conf/bda, conf/bigda}
# CCS                {399, <NA>}                {conf/ccs, conf/iastedCCS}
# CIC                {449, <NA>}               {conf/imaging, conf/coinco}
# CISIS               {473, 474}            {conf/cisis-spain, conf/cisis}
# CMC                     {<NA>}                 {conf/cmc, conf/membrane}
# CSWS                    {<NA>}                  {conf/csemws, conf/csws}
# DH                 {863, <NA>}                 {conf/dihu, conf/ehealth}
# ECBS               {795, <NA>}                {conf/ecbs, conf/ecbseerc}
# FG                {1029, <NA>}                       {conf/fgr, conf/fg}
# HIS               {1195, 1196}                     {conf/his2, conf/his}
# HPCA              {1220, <NA>}                  {conf/hpca, conf/cnhpca}
# HPCS                    {<NA>}                {conf/ieeehpcs, conf/hpcs}
# HSI                     {<NA>}                    {conf/hsi, conf/human}
# ICAIS             {1276, <NA>}                {conf/icccsec, conf/icais}
# ICAT                    {<NA>}                 {conf/icatech, conf/icat}
# ICC               {1294, <NA>}                   {conf/iotdcc, conf/icc}
# ICCC                    {<NA>}  {conf/iccc, conf/icccrea, conf/iccchina}
# ICCIP                   {<NA>}              {conf/iccip, conf/ifip11-10}
# ICCS        {1321, 1320, <NA>}              {conf/iccs, conf/iccS, <NA>}
# ICDM              {1336, 1337}                   {conf/incdm, conf/icdm}
# ICEC        {1345, 1346, <NA>}      {conf/icec, conf/iwec, conf/ACMicec}
# ICICS             {1385, <NA>}              {conf/icics, conf/IEEEicics}
# ICIS              {1393, <NA>}            {conf/ACISicis, conf/ISCAicis}
# ICON              {1437, <NA>}                {conf/icon, conf/icon-nlp}
# ICSC              {1460, <NA>}                   {conf/icsc, conf/semco}
# ICVS              {1501, <NA>}            {conf/icvs, conf/storytelling}
# IDC               {1521, 1520}                   {conf/acmidc, conf/idc}
# IHCI              {1550, <NA>}                   {conf/inhci, conf/ihci}
# ISCO                    {<NA>}                         {conf/isco, <NA>}
# ISI               {1711, <NA>}  {conf/intelligent, conf/isiwi, conf/isi}
# ISPA              {1738, <NA>}                   {conf/imspa, conf/ispa}
# ITC               {1779, 1405}                    {conf/icits, conf/itc}
# IV                {1803, 1804}                       {conf/iv, conf/ivs}
# JIST                    {<NA>}                         {conf/jist, <NA>}
# MCPR                    {<NA>}                   {conf/mcpr, conf/mcpr2}
# MobiSec                 {<NA>}             {conf/mobisec2, conf/mobisec}
# PROMISE                 {<NA>}            {conf/promise, conf/promisews}
# PSC                     {<NA>}               {conf/ps, conf/stringology}
# SC                      {<NA>}         {conf/metainformatics, conf/soco}
# SDE                     {<NA>}                    {conf/sde, conf/sdiev}
# SEC                     {<NA>}                     {conf/edge, conf/sec}
# SSS                     {<NA>}                     {conf/scss, conf/sss}
# SoCC              {2721, <NA>}                   {conf/socc, conf/cloud}
# WI                {3061, <NA>}   {conf/wirtschaftsinformatik, conf/webi}
#
#             length
# short_name
# ACE              2
# ACL              2
# ACSAC            2
# AH               2
# AIM              2
# AIPR             2
# BDA              2
# CCS              2
# CIC              2
# CISIS            2
# CMC              2
# CSWS             2
# DH               2
# ECBS             2
# FG               2
# HIS              2
# HPCA             2
# HPCS             2
# HSI              2
# ICAIS            2
# ICAT             2
# ICC              2
# ICCC             3
# ICCIP            2
# ICCS             3
# ICDM             2
# ICEC             3
# ICICS            2
# ICIS             2
# ICON             2
# ICSC             2
# ICVS             2
# IDC              2
# IHCI             2
# ISCO             2
# ISI              3
# ISPA             2
# ITC              2
# IV               2
# JIST             2
# MCPR             2
# MobiSec          2
# PROMISE          2
# PSC              2
# SC               2
# SDE              2
# SEC              2
# SSS              2
# SoCC             2
# WI               2
